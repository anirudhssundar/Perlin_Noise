# %%
import noise
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from scipy.misc import toimage
# %matplotlib inline

# %%
img = np.zeros((256,256))

shape = np.shape(img)

base = np.random.randint(10)
img = np.reshape([noise.pnoise2(i/90.0,j/90.0,3,base = base)
                  for i in range(256) for j in range(256)],(256,256))

# %%
plt.imshow(img)
plt.show()

# %%
toimage(img).show()
# Out:
# /home/anirudh/Documents/Sentdex_tut/anotherenv/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
#   """Entry point for launching an IPython kernel.

# %%
lightblue = [0,191,255]
blue = [65,105,225]
green = [34,139,34]
darkgreen = [0,100,0]
sandy = [210,180,140]
beach = [238, 214, 175]
snow = [255, 250, 250]
mountain = [139, 137, 137]

threshold = 0

def add_color2(world):
    color_world = np.zeros(world.shape+(3,))
    for i in range(shape[0]):
        for j in range(shape[1]):
            if world[i][j] < threshold + 0.05:
                color_world[i][j] = blue
            elif world[i][j] < threshold + 0.055:
                color_world[i][j] = sandy
            elif world[i][j] < threshold + 0.1:
                color_world[i][j] = beach
            elif world[i][j] < threshold + 0.2:
                color_world[i][j] = green
            elif world[i][j] < threshold + 0.25:
                color_world[i][j] = darkgreen
            elif world[i][j] < threshold + 0.3:
                color_world[i][j] = mountain
            elif world[i][j] < threshold + 0.7:
                color_world[i][j] = snow

    return color_world

island_world_grad = add_color2(img)
toimage(island_world_grad).show()
# Out:
# /home/anirudh/Documents/Sentdex_tut/anotherenv/lib/python2.7/site-packages/ipykernel_launcher.py:34: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X,Y = np.meshgrid(np.arange(256),np.arange(256))


ax.plot_surface(X,Y,img,cmap = 'terrain')
plt.show()

# %%
x, y = np.meshgrid(np.arange(256), np.arange(256))

noise =  np.random.normal(loc=0, scale=1, size=img.shape)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
X,Y = np.meshgrid(np.arange(256),np.arange(256))


ax.plot_surface(X,Y,noise,cmap = 'terrain')
plt.show()

# %%
toimage(noise).show()
# Out:
# /home/anirudh/Documents/Sentdex_tut/anotherenv/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
#   """Entry point for launching an IPython kernel.

# %%
lightblue = [0,191,255]
blue = [65,105,225]
green = [34,139,34]
darkgreen = [0,100,0]
sandy = [210,180,140]
beach = [238, 214, 175]
snow = [255, 250, 250]
mountain = [139, 137, 137]

threshold = 0

def add_color2(world):
    color_world = np.zeros(world.shape+(3,))
    for i in range(shape[0]):
        for j in range(shape[1]):
            if world[i][j] < threshold + 0.05:
                color_world[i][j] = blue
            elif world[i][j] < threshold + 0.055:
                color_world[i][j] = sandy
            elif world[i][j] < threshold + 0.1:
                color_world[i][j] = beach
            elif world[i][j] < threshold + 0.2:
                color_world[i][j] = green
            elif world[i][j] < threshold + 0.25:
                color_world[i][j] = darkgreen
            elif world[i][j] < threshold + 0.3:
                color_world[i][j] = mountain
            elif world[i][j] < threshold + 0.7:
                color_world[i][j] = snow

    return color_world

island_world_grad = add_color2(noise)
toimage(island_world_grad).show()
# Out:
# /home/anirudh/Documents/Sentdex_tut/anotherenv/lib/python2.7/site-packages/ipykernel_launcher.py:34: DeprecationWarning: `toimage` is deprecated!
# `toimage` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow's ``Image.fromarray`` directly instead.
